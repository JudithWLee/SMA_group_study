# %% [markdown]
# # 第一次讀書會報告
#
# 組別:第9組
#
# Date:2024/03/26

# %% [markdown]
# # 1.載入環境及安裝套件

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 載入套件
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
from datetime import datetime
from collections import Counter
from tqdm import tqdm

from wordcloud import WordCloud # pip install wordcloud
import matplotlib.pyplot as plt

# 下載斷句需要的資源
nltk.download('punkt')
# 下載POS tagger需要的資源
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
#下載停用詞
nltk.download('stopwords')

# %matplotlib inline

plt.rcParams['figure.figsize'] = [6, 4]
plt.rcParams['figure.dpi'] = 150
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# 設定圖的字體大小
plt.rcParams['font.size'] = 14

# 設定中文字體 (無法顯示的話可以試試‘Microsoft JhengHei’字體)
# 也可參考：https://pyecontech.com/2020/03/27/python_matplotlib_chinese/
plt.rcParams['font.sans-serif'] = ['Arial Unicode Ms']

# %% [markdown]
# # 2.資料前處理

# %% [markdown]
# ## 2.1資料蒐集
# 本組自Kaggle下載Amazon上有關Finee Food類的評論資料集。
# 本組自Kaggle下載Amazon上有關Finee Food類的評論資料集。
# 該資料集包括對來自亞馬遜的精美食品的評論。
# 這些資料的使用期限超過10年，包括1999年10月至2012年10月
# 約500,000條評論。評論包括產品和使用者資訊，評級以及純文字評論。
# 它還包括來自所有其他亞馬遜類別的評論。
#
# Data includes:
# *   Reviews from Oct 1999 - Oct 2012
# *   568,454 reviews
# *   256,059 users
# *   74,258 products
#
# 資料來源:https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews

# %%
##讀取資料集
Amazon_df = pd.read_csv('/content/drive/MyDrive/中山大學/社群媒體/Amazon Fine Food Reviews.csv')
Amazon_df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 10 columns]

# %%
#資料集資訊
Amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %% [markdown]
# 查看每一列資料的資料類型和資料總數
# > 發現：
# > 1. ProfileName有缺失值=568454-568438=16，缺失率=16/568454=0.002%
# > 2. Summary有缺失值=568454-568427=27，缺失率=27/568454=0.005%

# %%
#缺失值處理,由於樣本數較大，缺失值量較少，直接删除缺失值
Amazon_df = Amazon_df.dropna(subset = ['ProfileName','Summary'],how = 'any')
Amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 568401 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568401 non-null  int64
#  1   ProductId               568401 non-null  object
#  2   UserId                  568401 non-null  object
#  3   ProfileName             568401 non-null  object
#  4   HelpfulnessNumerator    568401 non-null  int64
#  5   HelpfulnessDenominator  568401 non-null  int64
#  6   Score                   568401 non-null  int64
#  7   Time                    568401 non-null  int64
#  8   Summary                 568401 non-null  object
#  9   Text                    568401 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 47.7+ MB

# %%
#重覆值處理
Amazon_df = Amazon_df.drop_duplicates(subset= ['ProductId','UserId','Score', 'Text'] ,keep = 'first')
Amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 567112 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      567112 non-null  int64
#  1   ProductId               567112 non-null  object
#  2   UserId                  567112 non-null  object
#  3   ProfileName             567112 non-null  object
#  4   HelpfulnessNumerator    567112 non-null  int64
#  5   HelpfulnessDenominator  567112 non-null  int64
#  6   Score                   567112 non-null  int64
#  7   Time                    567112 non-null  int64
#  8   Summary                 567112 non-null  object
#  9   Text                    567112 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 47.6+ MB

# %%
#異常值處理
Amazon_df.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  567112.000000         567112.000000           567112.000000
# mean   284251.391000              1.741402                2.223476
# std    164112.981657              7.640035                8.288355
# min         1.000000              0.000000                0.000000
# 25%    142118.750000              0.000000                0.000000
# 50%    284269.500000              0.000000                1.000000
# 75%    426375.250000              2.000000                2.000000
# max    568454.000000            866.000000              923.000000
#
#                Score          Time
# count  567112.000000  5.671120e+05
# mean        4.184136  1.296294e+09
# std         1.309316  4.803968e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311206e+09
# 75%         5.000000  1.332720e+09
# max         5.000000  1.351210e+09

# %% [markdown]
# 此部分為將時間轉換成datetime格式

# %%
'''
定義時間戳記轉換函數：
先使用datetime轉換時間戳記為datetime形式 例如”2016-11-30 06:12:49.750000“
再使用strftime函數分離出date
最後轉換為Series類型
'''
def changeTimstamp(timeCol):
    dateList = []
    for time in timeCol:
        #例如：datetime.fromtimestamp(1480486369.75) 轉換後為2016-11-30 06:12:49.750000格式
        dt = datetime.fromtimestamp(time)
        #分隔後僅剩2016-11-30
        date = dt.strftime("%Y-%m-%d")
        dateList.append(date)

    #將一維資料再轉換回Series類型
    dateSer = pd.Series(dateList)
    return dateSer
#獲取時間戳記一列
time = Amazon_df.loc[:, 'Time']
#使用轉換函數隔離出date
dateSer = changeTimstamp(time)

#修改這一列值
Amazon_df.loc[:, 'Time'] = dateSer

# %%
#字串轉換為日期類型
Amazon_df.loc[:, 'Time'] = pd.to_datetime(Amazon_df.loc[:, 'Time'],
                                         format = '%Y-%m-%d',
                                         errors= 'coerce')
'''
轉換日期過程中可能會發生不符合日期格式的數值轉換為空值
還需刪除空值
'''
Amazon_df = Amazon_df.dropna(subset = ['Time'])

# %%
#按日期升冪排序
Amazon_df = Amazon_df.sort_values(by = 'Time',
                                 ascending = True,
                                 na_position = 'first')
#排序後重命名行號（index）：排序後的列索引值是之前的行號，需要修改成從0到N的升冪索引值
Amazon_df = Amazon_df.reset_index(drop = True)

# %%
Amazon_df
# Out:
#             Id   ProductId          UserId  \
# 0       150137  B00092M46C  A2Z3LXAVPNP1JU
# 1       150114  B003YBP6Q0   AB4L49O201FRA
# 2       450720  B000N2VR48  A14N5GF0K9H6RU
# 3       229681  B007PUYUG8   A8GSFLE5X2CH4
# 4       450742  B0000V8IOE  A1D98WW2YMYD7F
# ...        ...         ...             ...
# 565770  528830  B0001R050C  A19JDXB5R33C7R
# 565771  413381  B00106NDNY   AGCJCYYJX7LN4
# 565772   15578  B000255OIG  A2EIKJ2XFU6J9T
# 565773   93179  B0012KK45S  A1AYGEOF1UO87L
# 565774   93525  B000EHP522   AZ50F6MW6LWOD
#
#                                            ProfileName  HelpfulnessNumerator  \
# 0                                 Sue Deneke "DaneMom"                     4
# 1       Julie A. Smith "Julie @ Knitting and Sundries"                     2
# 2                                       Cameron Seider                     1
# 3                                           crystal vh                     2
# 4                                               Jeff F                     0
# ...                                                ...                   ...
# 565770                                         WryGuy2                     0
# 565771                   Michael F. Braddock "Mr Fade"                     3
# 565772                                   Wayne in Indy                     2
# 565773                         P. Davis "Amazon Lover"                     0
# 565774                                        Jokerfan                     0
#
#         HelpfulnessDenominator  Score                 Time  \
# 0                            4      5  1999-10-08 00:00:00
# 1                            5      2  1999-10-25 00:00:00
# 2                            1      5  1999-12-02 00:00:00
# 3                            3      5  1999-12-06 00:00:00
# 4                            0      5  1999-12-06 00:00:00
# ...                        ...    ...                  ...
# 565770                       0      4  2012-10-26 00:00:00
# 565771                       3      5  2012-10-26 00:00:00
# 565772                       2      4  2012-10-26 00:00:00
# 565773                       0      5  2012-10-26 00:00:00
# 565774                       1      5  2012-10-26 00:00:00
#
#                                     Summary  \
# 0                      Perfect for tiramisu
# 1       The taste leaves much to be desired
# 2              High quality! Fast delivery!
# 3            Taste great!Feels even better!
# 4                               KONA PLEASE
# ...                                     ...
# 565770      A darned good Mother's Day gift
# 565771           Firm Bean - Pleasing Color
# 565772                  Great but expensive
# 565773                                  FF1
# 565774               Great for hot weather!
#
#                                                      Text
# 0       These ladyfingers have the perfect texture nee...
# 1       I purchased these for my vegetarian college st...
# 2       I received my product much sooner then I antic...
# 3       This is by far the best blue lotus out there!I...
# 4       The wife and i bought this to use with our new...
# ...                                                   ...
# 565770  I bought this product, the "Art of Appreciatio...
# 565771  Cooked up nice... firm texture with beans reta...
# 565772  It is a great product. It is very nutritional ...
# 565773  The Fancy Feast arrived very quickly, in perfe...
# 565774  These bars can be a little messy, as some revi...
#
# [565775 rows x 10 columns]

# %%
Amazon_df['Time'] = pd.to_datetime(Amazon_df['Time'])

# %%
#將年份取出並增加一個columns
Amazon_df['Year'] = Amazon_df['Time'].dt.strftime("%Y")
Amazon_df
# Out:
#             Id   ProductId          UserId  \
# 0       150137  B00092M46C  A2Z3LXAVPNP1JU
# 1       150114  B003YBP6Q0   AB4L49O201FRA
# 2       450720  B000N2VR48  A14N5GF0K9H6RU
# 3       229681  B007PUYUG8   A8GSFLE5X2CH4
# 4       450742  B0000V8IOE  A1D98WW2YMYD7F
# ...        ...         ...             ...
# 565770  528830  B0001R050C  A19JDXB5R33C7R
# 565771  413381  B00106NDNY   AGCJCYYJX7LN4
# 565772   15578  B000255OIG  A2EIKJ2XFU6J9T
# 565773   93179  B0012KK45S  A1AYGEOF1UO87L
# 565774   93525  B000EHP522   AZ50F6MW6LWOD
#
#                                            ProfileName  HelpfulnessNumerator  \
# 0                                 Sue Deneke "DaneMom"                     4
# 1       Julie A. Smith "Julie @ Knitting and Sundries"                     2
# 2                                       Cameron Seider                     1
# 3                                           crystal vh                     2
# 4                                               Jeff F                     0
# ...                                                ...                   ...
# 565770                                         WryGuy2                     0
# 565771                   Michael F. Braddock "Mr Fade"                     3
# 565772                                   Wayne in Indy                     2
# 565773                         P. Davis "Amazon Lover"                     0
# 565774                                        Jokerfan                     0
#
#         HelpfulnessDenominator  Score       Time  \
# 0                            4      5 1999-10-08
# 1                            5      2 1999-10-25
# 2                            1      5 1999-12-02
# 3                            3      5 1999-12-06
# 4                            0      5 1999-12-06
# ...                        ...    ...        ...
# 565770                       0      4 2012-10-26
# 565771                       3      5 2012-10-26
# 565772                       2      4 2012-10-26
# 565773                       0      5 2012-10-26
# 565774                       1      5 2012-10-26
#
#                                     Summary  \
# 0                      Perfect for tiramisu
# 1       The taste leaves much to be desired
# 2              High quality! Fast delivery!
# 3            Taste great!Feels even better!
# 4                               KONA PLEASE
# ...                                     ...
# 565770      A darned good Mother's Day gift
# 565771           Firm Bean - Pleasing Color
# 565772                  Great but expensive
# 565773                                  FF1
# 565774               Great for hot weather!
#
#                                                      Text  Year
# 0       These ladyfingers have the perfect texture nee...  1999
# 1       I purchased these for my vegetarian college st...  1999
# 2       I received my product much sooner then I antic...  1999
# 3       This is by far the best blue lotus out there!I...  1999
# 4       The wife and i bought this to use with our new...  1999
# ...                                                   ...   ...
# 565770  I bought this product, the "Art of Appreciatio...  2012
# 565771  Cooked up nice... firm texture with beans reta...  2012
# 565772  It is a great product. It is very nutritional ...  2012
# 565773  The Fancy Feast arrived very quickly, in perfe...  2012
# 565774  These bars can be a little messy, as some revi...  2012
#
# [565775 rows x 11 columns]

# %% [markdown]
# 因本資料集資料量 `較大`，執行過程效能較為不佳，故改為選取: `1999年`到`2007年` 共 `30911` 筆資料來進行以下研究

# %%
#資料選取
filt = (Amazon_df['Year'] < "2008")
Amazon_df_filt=Amazon_df[filt]
Amazon_df_filt
# Out:
#            Id   ProductId          UserId  \
# 0      150137  B00092M46C  A2Z3LXAVPNP1JU
# 1      150114  B003YBP6Q0   AB4L49O201FRA
# 2      450720  B000N2VR48  A14N5GF0K9H6RU
# 3      229681  B007PUYUG8   A8GSFLE5X2CH4
# 4      450742  B0000V8IOE  A1D98WW2YMYD7F
# ...       ...         ...             ...
# 30924  350087  B000EMU2BG  A2H5ROZZC74XN1
# 30925  314472  B0000U1OL4  A1UQBFCERIP7VJ
# 30926  287192  B009K2BBT8  A27HYAB5IYG0JS
# 30927  428336  B0054ETSKK   A7GF6V6KYUVAM
# 30928   27653  B003U0O0X0   AMKDHTQ3NC82B
#
#                                           ProfileName  HelpfulnessNumerator  \
# 0                                Sue Deneke "DaneMom"                     4
# 1      Julie A. Smith "Julie @ Knitting and Sundries"                     2
# 2                                      Cameron Seider                     1
# 3                                          crystal vh                     2
# 4                                              Jeff F                     0
# ...                                               ...                   ...
# 30924                                     Rock Bottom                     1
# 30925                                  Margaret Picky                     4
# 30926                              charlotte crawford                    69
# 30927                                      cllgal2005                     0
# 30928                               Sandra Guadagnoli                     2
#
#        HelpfulnessDenominator  Score       Time  \
# 0                           4      5 1999-10-08
# 1                           5      2 1999-10-25
# 2                           1      5 1999-12-02
# 3                           3      5 1999-12-06
# 4                           0      5 1999-12-06
# ...                       ...    ...        ...
# 30924                       1      5 2007-12-31
# 30925                       4      5 2007-12-31
# 30926                      71      5 2007-12-31
# 30927                       1      2 2007-12-31
# 30928                       2      1 2007-12-31
#
#                                     Summary  \
# 0                      Perfect for tiramisu
# 1       The taste leaves much to be desired
# 2              High quality! Fast delivery!
# 3            Taste great!Feels even better!
# 4                               KONA PLEASE
# ...                                     ...
# 30924   VERY TASTY ON A COLD WINTER'S NIGHT
# 30925        Excellent quality mole poblano
# 30926                           Techno-BEST
# 30927  Rock Candy for Birthday Party Favors
# 30928                        Changed flavor
#
#                                                     Text  Year
# 0      These ladyfingers have the perfect texture nee...  1999
# 1      I purchased these for my vegetarian college st...  1999
# 2      I received my product much sooner then I antic...  1999
# 3      This is by far the best blue lotus out there!I...  1999
# 4      The wife and i bought this to use with our new...  1999
# ...                                                  ...   ...
# 30924  EASY TO MAKE AND THE TASTE IS JUST GREAT. LOVE...  2007
# 30925  This is excellent quality mole poblana sauce. ...  2007
# 30926  My disclaimer- I'm a coffee geek.  There's a f...  2007
# 30927  I bought this product to use as party favors f...  2007
# 30928  I was so excited to find these again after all...  2007
#
# [30929 rows x 11 columns]

# %%
reviews_year  = Amazon_df_filt["Year"]

# %%
#計算出不同年份的評論筆數，並轉成dataframe
Amazon_df_count = pd.DataFrame({
    'year': Amazon_df_filt.groupby(reviews_year).size().index,
    'content': Amazon_df_filt.groupby(reviews_year).size().values
#     'word': token_df.groupby(reviews_year).size().values,
})
Amazon_df_count[:10]
# Out:
#    year  content
# 0  1999        6
# 1  2000       32
# 2  2001       13
# 3  2002       73
# 4  2003      131
# 5  2004      560
# 6  2005     1328
# 7  2006     6633
# 8  2007    22153

# %%
#畫出年份句數折線圖
plt.plot(Amazon_df_count['year'].values, Amazon_df_count['content'].values ,label = 'content')
#plt.plot(Amazon_df_count['year'].values, reviews_count['word'].values, label = 'words')

plt.title('年份句數折線圖') # 標題
plt.xlabel('year') # x軸標題
plt.ylabel('number') # y軸標題
plt.legend(fontsize=8) # 顯示label
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20221 (\N{CJK UNIFIED IDEOGRAPH-4EFD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21477 (\N{CJK UNIFIED IDEOGRAPH-53E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25976 (\N{CJK UNIFIED IDEOGRAPH-6578}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25240 (\N{CJK UNIFIED IDEOGRAPH-6298}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22294 (\N{CJK UNIFIED IDEOGRAPH-5716}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms
# WARNING:matplotlib.font_manager:findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial Unicode Ms

# %%
#選擇前1999年到2007年的30911則評論
content_df= pd.DataFrame(Amazon_df['Text'].iloc[:30911].values, columns=['sentence'])
#content_df = Amazon_df['Text'].iloc[:30912].values
year_df = pd.DataFrame(Amazon_df['Year'].iloc[:30911].values, columns=['year'])
pId_df = pd.DataFrame(Amazon_df['ProductId'].iloc[:30911].values, columns=['pId'])

new_content_df = {
     "year" :year_df["year"],
     "pId" : pId_df["pId"],
     "sentence" :content_df["sentence"]

 }
content_df = pd.DataFrame(new_content_df)
content_df
# Out:
#        year         pId                                           sentence
# 0      1999  B00092M46C  These ladyfingers have the perfect texture nee...
# 1      1999  B003YBP6Q0  I purchased these for my vegetarian college st...
# 2      1999  B000N2VR48  I received my product much sooner then I antic...
# 3      1999  B007PUYUG8  This is by far the best blue lotus out there!I...
# 4      1999  B0000V8IOE  The wife and i bought this to use with our new...
# ...     ...         ...                                                ...
# 30906  2007  B006ZZC0FW  Certainly flavorful, but less body than I usua...
# 30907  2007  B0034EDMLI  Kind bars travel well. Purse,pocket,or car the...
# 30908  2007  B0002QEHOM  The difference between this and the usual oat ...
# 30909  2007  B002MGCWBU  Although they are a good idea in theory, these...
# 30910  2007  B000JWM7E6  THIS OIL SURE DOES STINK!!!!. SMELLS LIKE ANIM...
#
# [30911 rows x 3 columns]

# %% [markdown]
# ## 2.2資料清洗

# %% [markdown]
# 移除無意義字、標點符號
#
#
# 清除文本中的標點符號、數字以及換行符號，並將長度小於1的句子刪除

# %%
# 刪除標點符號/數字/換行符號
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r'[^\w\s]','', x))  #只留下英文字母和空格(包含換行符號)
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r'[\n_-]+',' ', x)) #將換行符號替換成空格
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r"http\S+",' ', x))#移除有http的網址
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r'[?|!|\'|"|#]',' ', x))#去除評論中的各種符號
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r'[.|,|)|(|\|/]',' ', x))#去除評論中的各種符號
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r"\S*\d\S*",' ', x))#去除單字中的數字
content_df["sentence"] = content_df["sentence"].apply(lambda x: re.sub(r'[^A-Za-z0-9]+',' ', x))#去除評論中的特殊字符

# 刪除長度小於1的句子
content_df = content_df[~content_df["sentence"].str.len() < 1]

content_df
# Out:
#        year         pId                                           sentence
# 0      1999  B00092M46C  These ladyfingers have the perfect texture nee...
# 1      1999  B003YBP6Q0  I purchased these for my vegetarian college st...
# 2      1999  B000N2VR48  I received my product much sooner then I antic...
# 3      1999  B007PUYUG8  This is by far the best blue lotus out thereI ...
# 4      1999  B0000V8IOE  The wife and i bought this to use with our new...
# ...     ...         ...                                                ...
# 30906  2007  B006ZZC0FW  Certainly flavorful but less body than I usual...
# 30907  2007  B0034EDMLI  Kind bars travel well Pursepocketor car these ...
# 30908  2007  B0002QEHOM  The difference between this and the usual oat ...
# 30909  2007  B002MGCWBU  Although they are a good idea in theory these ...
# 30910  2007  B000JWM7E6  THIS OIL SURE DOES STINK SMELLS LIKE ANIMAL PO...
#
# [30911 rows x 3 columns]

# %%
#此處為將清洗好的資料存成csv檔匯出
content_df.to_csv("test_content_df.csv", encoding = 'utf-8',index = False)

# %% [markdown]
# ## 2.3斷句及字詞正規化

# %% [markdown]
# 本小組在此研究選擇使用`spacy`的英文`en_core_web_sm`模型將評論同時進行token及字型還原Stemming

# %%
# pip install spacy
# 下載網址：https://github.com/explosion/spacy-models/releases?q=en_core_web_sm&expanded=true
# pip install "/Users/billyke/en_core_web_sm-3.7.1-py3-none-any.whl"
# !python3 -m spacy download en_core_web_sm
#使用spacy將評論同時進行token及字型還原

import spacy
nlp = spacy.load('en_core_web_sm')
def tokenize_and_lemmatize(sentence):
    doc = nlp(sentence)
    lemmatized_tokens = [token.lemma_ for token in doc]
    return lemmatized_tokens

def pos(sentence):
    doc = nlp(sentence)
    token_pos = [token.pos_ for token in doc]
    return token_pos

# %%
#生成token
token_df = content_df.assign(token = content_df['sentence'].apply(tokenize_and_lemmatize)).explode('token')

#生成pos
token_df = token_df.assign(token_pos = content_df['sentence'].apply(pos)).explode('token_pos')

# %%
token_df

# %% [markdown]
# 字母大小寫轉換

# %%
lowerWord_df = token_df.assign(word = token_df['token'].str.lower())
lowerWord_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'token'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-d854f68dfef0> in <cell line: 1>()
# ----> 1 lowerWord_df = token_df.assign(word = token_df['token'].str.lower())
#       2 lowerWord_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'token'

# %% [markdown]
# ## 2.4刪除停用字

# %% [markdown]
# 使用nltk的'english'停用字字典

# %%
# 初次使用需要安裝nltk中的停用字資源
nltk.download('stopwords')

# 使用nltk的stop_words
stops = stopwords.words('english')

# %%
noStop_df = lowerWord_df[~lowerWord_df['word'].isin(stops)]
noStop_df

# %% [markdown]
# 計算詞頻

# %%
#計算出現的詞頻，列出最常出現的20個詞彙
freq_df = pd.DataFrame(noStop_df['word'].value_counts()).reset_index()
freq_df.columns = ['word', 'freq']
freq_df.head(20)

# %%
#畫出詞頻圖
freq_df.iloc[:10].plot.barh(x='word', y='freq').invert_yaxis()
plt.show()

# %% [markdown]
# 從文字雲中可以明顯地看出一些對後續情緒分析較無影響的詞，例如:'br', 'would', 'much', 'one','use','also','could','many','amazon'

# %%
text = freq_df.set_index('word').to_dict()
wordcloud = WordCloud(scale = 4, background_color = 'white', max_words=100).generate_from_frequencies(text['freq'])
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# 將前述無影響的詞加入停用字字典

# %%
# 手動加入停用字
newStops = ['br', 'would', 'much', 'one','use','also','could','many','amazon']
stops.extend(newStops)

# %% [markdown]
# 做第二次刪除停用字

# %%
noStop2_df = noStop_df[~noStop_df['word'].isin(stops)]
noStop2_df

# %%
#重新計算並列出詞頻
freq_df2 = pd.DataFrame(noStop2_df['word'].value_counts())
freq_df2 = freq_df2.reset_index()
freq_df2.columns = ['word', 'freq']
freq_df2.head(15)

# %%
freq_df2.iloc[:10].plot.barh(x='word', y='freq').invert_yaxis()
plt.show()

# %%
#新的文字雲圖
text_2 = freq_df2.set_index('word').to_dict()
wordcloud_2 = WordCloud(scale = 4, background_color = 'white', max_words=100).generate_from_frequencies(text_2['freq'])
plt.figure(figsize=(10,5))
plt.imshow(wordcloud_2)
plt.axis('off')
plt.show()

# %% [markdown]
# # 3.情緒分析

# %%
# pip install transformers
# pip install torch

from transformers import BertTokenizer, BertModel
from sklearn.linear_model import LogisticRegression
import torch
import numpy as np

# %%
#合併stem_token
aggregated_df = noStop2_df.groupby(noStop2_df.index)['word'].apply(lambda x: ' '.join(x)).reset_index(name='aggregated_words')
aggregated_df
# Out:
#        index                                   aggregated_words
# 0          0  ladyfinger perfect texture need make tiramisu ...
# 1          1  purchase vegetarian college student subscribe ...
# 2          2  receive product soon anticipate merchandise pa...
# 3          3  far good blue lotus therei drink alcohol take ...
# 4          4  wife buy new coffee grinder flavor full smooth...
# ...      ...                                                ...
# 30906  30906  certainly flavorful less body usually prefer t...
# 30907  30907  kind bar travel well pursepocketor car take he...
# 30908  30908  difference usual oat meal astounding even talk...
# 30909  30909  although good idea theory bottle small think m...
# 30910  30910  oil sure stink smells like animal poobut soooo...
#
# [30911 rows x 2 columns]

# %%
pId_df = Amazon_df['ProductId']
aggregated_df = aggregated_df.join(pId_df)

# %%
aggregated_df
# Out:
#        index                                   aggregated_words   ProductId
# 0          0  ladyfinger perfect texture need make tiramisu ...  B00092M46C
# 1          1  purchase vegetarian college student subscribe ...  B003YBP6Q0
# 2          2  receive product soon anticipate merchandise pa...  B000N2VR48
# 3          3  far good blue lotus therei drink alcohol take ...  B007PUYUG8
# 4          4  wife buy new coffee grinder flavor full smooth...  B0000V8IOE
# ...      ...                                                ...         ...
# 30906  30906  certainly flavorful less body usually prefer t...  B006ZZC0FW
# 30907  30907  kind bar travel well pursepocketor car take he...  B0034EDMLI
# 30908  30908  difference usual oat meal astounding even talk...  B0002QEHOM
# 30909  30909  although good idea theory bottle small think m...  B002MGCWBU
# 30910  30910  oil sure stink smells like animal poobut soooo...  B000JWM7E6
#
# [30911 rows x 3 columns]

# %% [markdown]
# ## **3.1使用NLTK_Vader**
#
# NLTK（Natural Language Toolkit）中的VADER是用於文本情緒分析的工具，特別適用於社群媒體和網路文本。 VADER結合了一個預先定義的情緒字典和一系列基於規則的方法，能夠有效地識別和量化文本中的情感傾向。它特別擅長處理網路語言的特點，包括表情符號、俚語和網路特有的拼字方式。
#
# VADER return like {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.6249}，可以讓我們看出負面、中性及正面詞的比例，第四個'compound'基本上是一個指標，是所有評級的標準化值，範圍在 -1 到 1 之間。根據這些範圍，我們可以確定最終情緒是正面、負面還是中性。

# %% [markdown]
# **因此我們將compound小於0標記為negative，大於0為positive**。
#
# 此部分本小組用於研究評論句子的部分

# %%
import requests
import pandas as pd
import csv
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
#情緒分析
nltk.download('vader_lexicon')

# Initialize the SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# Create a list to hold sentiment scores
sentiment_scores = []

# Iterate over each row in the DataFrame
for i in range(len(aggregated_df)):
    text = aggregated_df.at[i, 'aggregated_words']
    # Perform sentiment analysis
    score = sid.polarity_scores(text)
    #思考剛好＝0
    if score['compound'] >0:
      sentiment_scores.append('positive')
    else:
      sentiment_scores.append('negative')
    # Append the compound score to the list
    #sentiment_scores.append(score['compound'])

# Add the list of scores as a new column in the DataFrame
aggregated_df['sentiment_score'] = sentiment_scores

# Display the DataFrame to verify
aggregated_df2 = aggregated_df
aggregated_df2
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/billyke/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#        index                                   aggregated_words  \
# 0          0  starter antisplenda fanatic user year despite ...
# 1          1  end throw away hummus salty bitter edamame not...
# 2          2  sure someone give star review berry fresh tast...
# 3          3  like product review reader take negative feedb...
# 4          4  prepare red espresso rooibos tea espresso regu...
# ...      ...                                                ...
# 30906  30906  give treat little yorkie two year absolutely l...
# 30907  30907  disagree review love little bit crunch otherwi...
# 30908  30908  buy cookie easter gift two different family me...
# 30909  30909  everyone love pocky say lie lol pocky arrive g...
# 30910  30910  still food reviewer problem turn free coffee s...
#
#       sentiment_score
# 0            positive
# 1            negative
# 2            positive
# 3            negative
# 4            positive
# ...               ...
# 30906        positive
# 30907        positive
# 30908        positive
# 30909        positive
# 30910        positive
#
# [30911 rows x 3 columns]

# %%
#生成含有年份與情緒分數的dataframe
aggregated_df_clean = {
    "index" :aggregated_df2["index"],
    "aggregated_words" :aggregated_df2["aggregated_words"],
    "year":Amazon_df_filt["Year"],
    "sentiment_score" : aggregated_df2["sentiment_score"]
}

aggregated_df_new = pd.DataFrame(aggregated_df_clean)
aggregated_df_new
# Out:
#        index                                   aggregated_words  year  \
# 0          0  starter antisplenda fanatic user year despite ...  1999
# 1          1  end throw away hummus salty bitter edamame not...  1999
# 2          2  sure someone give star review berry fresh tast...  1999
# 3          3  like product review reader take negative feedb...  1999
# 4          4  prepare red espresso rooibos tea espresso regu...  1999
# ...      ...                                                ...   ...
# 30906  30906  give treat little yorkie two year absolutely l...  2007
# 30907  30907  disagree review love little bit crunch otherwi...  2007
# 30908  30908  buy cookie easter gift two different family me...  2007
# 30909  30909  everyone love pocky say lie lol pocky arrive g...  2007
# 30910  30910  still food reviewer problem turn free coffee s...  2007
#
#       sentiment_score
# 0            positive
# 1            negative
# 2            positive
# 3            negative
# 4            positive
# ...               ...
# 30906        positive
# 30907        positive
# 30908        positive
# 30909        positive
# 30910        positive
#
# [30911 rows x 4 columns]

# %% [markdown]
# ### 依年分類正面評論及負面評論

# %%
# 算出句子情緒總和(sentiment_count)

sentiment_count = pd.DataFrame(aggregated_df_new.groupby(['year', 'sentiment_score']).size()).reset_index()

mask = (sentiment_count['sentiment_score'] == "positive") | (sentiment_count['sentiment_score'] == "negative")
sentiment_count = sentiment_count.loc[mask]

sentiment_count = sentiment_count.rename(columns={0: 'size'})
sentiment_count
# Out:
#     year sentiment_score   size
# 0   1999        negative      2
# 1   1999        positive      4
# 2   2000        negative      3
# 3   2000        positive     29
# 4   2001        negative      1
# 5   2001        positive     12
# 6   2002        negative      2
# 7   2002        positive     71
# 8   2003        negative     12
# 9   2003        positive    120
# 10  2004        negative     60
# 11  2004        positive    498
# 12  2005        negative    134
# 13  2005        positive   1193
# 14  2006        negative    576
# 15  2006        positive   6041
# 16  2007        negative   2012
# 17  2007        positive  20141

# %%
#算出不同年份的正負向情緒
pos = sentiment_count[sentiment_count['sentiment_score']=='positive']
neg = sentiment_count[sentiment_count['sentiment_score']=='negative']
pos
# Out:
#     year sentiment_score   size
# 1   1999        positive      4
# 3   2000        positive     29
# 5   2001        positive     12
# 7   2002        positive     71
# 9   2003        positive    120
# 11  2004        positive    498
# 13  2005        positive   1193
# 15  2006        positive   6041
# 17  2007        positive  20141

# %%
neg
# Out:
#     year sentiment_score  size
# 0   1999        negative     2
# 2   2000        negative     3
# 4   2001        negative     1
# 6   2002        negative     2
# 8   2003        negative    12
# 10  2004        negative    60
# 12  2005        negative   134
# 14  2006        negative   576
# 16  2007        negative  2012

# %%
# you can find other color pattern here: https://matplotlib.org/stable/gallery/color/named_colors.html
#繪出正負向數目長條\\
colors = ["tab:blue",  "tab:orange"]
fig, ax = plt.subplots()

ax.bar(pos['year'],
       pos['size'],
       color = colors[0],
       alpha = 0.4,
       align='center')
ax.bar(neg['year'],
       neg['size'],
       color = colors[1],
       alpha = 0.4,
       align='center')
plt.xlabel('year')
plt.ylabel('size')

ax.legend(['positive','negative'], loc ='upper right')
plt.show()

# %%
#可查詢某一年的評論句正負向數量
sentiment_count[sentiment_count['year'] == "2000"]
# Out:
#    year sentiment_score  size
# 2  2000        negative     3
# 3  2000        positive    29

# %%
#計算情緒比例
sentiment_count.groupby('year')['size'].transform(lambda n : n/n.sum())
# Out:
# 0     0.333333
# 1     0.666667
# 2     0.093750
# 3     0.906250
# 4     0.076923
# 5     0.923077
# 6     0.027397
# 7     0.972603
# 8     0.090909
# 9     0.909091
# 10    0.107527
# 11    0.892473
# 12    0.100980
# 13    0.899020
# 14    0.087049
# 15    0.912951
# 16    0.090823
# 17    0.909177
# Name: size, dtype: float64

# %%
sentiment_count = sentiment_count.assign(
    ratio=sentiment_count.groupby("year")["size"].transform(lambda n: n / n.sum())
)
sentiment_count
# Out:
#     year sentiment_score   size     ratio
# 0   1999        negative      2  0.333333
# 1   1999        positive      4  0.666667
# 2   2000        negative      3  0.093750
# 3   2000        positive     29  0.906250
# 4   2001        negative      1  0.076923
# 5   2001        positive     12  0.923077
# 6   2002        negative      2  0.027397
# 7   2002        positive     71  0.972603
# 8   2003        negative     12  0.090909
# 9   2003        positive    120  0.909091
# 10  2004        negative     60  0.107527
# 11  2004        positive    498  0.892473
# 12  2005        negative    134  0.100980
# 13  2005        positive   1193  0.899020
# 14  2006        negative    576  0.087049
# 15  2006        positive   6041  0.912951
# 16  2007        negative   2012  0.090823
# 17  2007        positive  20141  0.909177

# %%
#畫出不同年份正負面折線圖
pos = sentiment_count[sentiment_count['sentiment_score']=='positive']
neg = sentiment_count[sentiment_count['sentiment_score']=='negative']
fig, ax = plt.subplots()

ax.plot(pos['year'],
       pos['ratio'],
       color = colors[0])
ax.plot(neg['year'],
       neg['ratio'],
       color = colors[1])
plt.xlabel('year')
plt.ylabel('ratio')

ax.legend(['positive','negative'], loc ='upper right')

# %%
#除去空值，整理出不同年份正負面評論數量
mask = ~aggregated_df_new['sentiment_score'].isna()
text_sentiment_value = sentiment_count.pivot_table(index='year', columns='sentiment_score', values='size', fill_value=0).reset_index().rename_axis(None, axis=1)
text_sentiment_value.head(10)
# Out:
#    year  negative  positive
# 0  1999         2         4
# 1  2000         3        29
# 2  2001         1        12
# 3  2002         2        71
# 4  2003        12       120
# 5  2004        60       498
# 6  2005       134      1193
# 7  2006       576      6041
# 8  2007      2012     20141

# %%
# sentiment 計算方式: positive - anger - anx - negative - sad，以此計算情緒分數
text_sentiment_value["sentiment_value"] = (
    text_sentiment_value["positive"]
    - text_sentiment_value["negative"]
)
text_sentiment_value.head(10)
# Out:
#    year  negative  positive  sentiment_value
# 0  1999         2         4                2
# 1  2000         3        29               26
# 2  2001         1        12               11
# 3  2002         2        71               69
# 4  2003        12       120              108
# 5  2004        60       498              438
# 6  2005       134      1193             1059
# 7  2006       576      6041             5465
# 8  2007      2012     20141            18129

# %%
#繪出折線圖
fig, ax = plt.subplots()
ax.plot(text_sentiment_value['year'], text_sentiment_value["sentiment_value"])
ax.set_xlabel('year')
ax.set_ylabel('sentiment value')
# Out:
# Text(0, 0.5, 'sentiment value')

# %% [markdown]
# ## **3.2使用LIWC_EN**
# 此部分本小組改成嘗試用liwc情緒字典來做情緒分析，主要著重在評論當中
# "詞"的部分

# %%
# 讀取情緒字典
en_dict_path = "2024_study_group7_1/dict/liwc/LIWC_EN.csv"
liwc_dict = pd.read_csv(en_dict_path)
liwc_dict = liwc_dict.rename(columns={'name': 'word', "class": 'sentiments'})
liwc_dict
# Out:
#            word sentiments
# 0            (:     affect
# 1            ):     affect
# 2            :(     affect
# 3            :)     affect
# 4       abandon     affect
# ...         ...        ...
# 3280      whine        sad
# 3281    whining        sad
# 3282        woe        sad
# 3283  worthless        sad
# 3284      yearn        sad
#
# [3285 rows x 2 columns]

# %%
noStop2_df
# Out:
#        year                                           sentence        token  \
# 0      1999  For starters Im not an antiSplenda fanatic Ive...      starter
# 0      1999  For starters Im not an antiSplenda fanatic Ive...  antiSplenda
# 0      1999  For starters Im not an antiSplenda fanatic Ive...      fanatic
# 0      1999  For starters Im not an antiSplenda fanatic Ive...         user
# 0      1999  For starters Im not an antiSplenda fanatic Ive...         year
# ...     ...                                                ...          ...
# 30910  2007  Im still not a food reviewer The problem is th...         make
# 30910  2007  Im still not a food reviewer The problem is th...         life
# 30910  2007  Im still not a food reviewer The problem is th...       fulfil
# 30910  2007  Im still not a food reviewer The problem is th...       fairly
# 30910  2007  Im still not a food reviewer The problem is th...         sure
#
#               word
# 0          starter
# 0      antisplenda
# 0          fanatic
# 0             user
# 0             year
# ...            ...
# 30910         make
# 30910         life
# 30910       fulfil
# 30910       fairly
# 30910         sure
#
# [1164883 rows x 4 columns]

# %%
text_liwc_df2 = pd.merge(noStop2_df, liwc_dict, how = 'left')
text_liwc_df2
# Out:
#          year                                           sentence        token  \
# 0        1999  For starters Im not an antiSplenda fanatic Ive...      starter
# 1        1999  For starters Im not an antiSplenda fanatic Ive...  antiSplenda
# 2        1999  For starters Im not an antiSplenda fanatic Ive...      fanatic
# 3        1999  For starters Im not an antiSplenda fanatic Ive...         user
# 4        1999  For starters Im not an antiSplenda fanatic Ive...         year
# ...       ...                                                ...          ...
# 1306189  2007  Im still not a food reviewer The problem is th...         life
# 1306190  2007  Im still not a food reviewer The problem is th...       fulfil
# 1306191  2007  Im still not a food reviewer The problem is th...       fairly
# 1306192  2007  Im still not a food reviewer The problem is th...         sure
# 1306193  2007  Im still not a food reviewer The problem is th...         sure
#
#                 word sentiments
# 0            starter        NaN
# 1        antisplenda        NaN
# 2            fanatic        NaN
# 3               user        NaN
# 4               year        NaN
# ...              ...        ...
# 1306189         life        NaN
# 1306190       fulfil        NaN
# 1306191       fairly        NaN
# 1306192         sure     affect
# 1306193         sure   positive
#
# [1306194 rows x 5 columns]

# %% [markdown]
# ### 依年分類正面評論及負面評論
# 以下方法同上，但主要針對詞的部分

# %%
# 算出字詞情緒總和(sentiment_count)

sentiment_count2 = pd.DataFrame(text_liwc_df2.groupby(['year', 'sentiments']).size()).reset_index()

mask = (sentiment_count2['sentiments'] == "positive") | (sentiment_count2['sentiments'] == "negative")
sentiment_count2 = sentiment_count2.loc[mask]

sentiment_count2 = sentiment_count2.rename(columns={0: 'size'})
sentiment_count2
# Out:
#     year sentiments   size
# 3   1999   negative      9
# 4   1999   positive     22
# 8   2000   negative     15
# 9   2000   positive    104
# 14  2001   negative     14
# 15  2001   positive     46
# 20  2002   negative     57
# 21  2002   positive    359
# 26  2003   negative    100
# 27  2003   positive    523
# 32  2004   negative    432
# 33  2004   positive   2012
# 38  2005   negative   1049
# 39  2005   positive   4756
# 44  2006   negative   4626
# 45  2006   positive  23298
# 50  2007   negative  15966
# 51  2007   positive  76998

# %%
#列出正負面詞彙數量
pos2 = sentiment_count2[sentiment_count2['sentiments']=='positive']
neg2 = sentiment_count2[sentiment_count2['sentiments']=='negative']
pos2
# Out:
#     year sentiments   size
# 4   1999   positive     22
# 9   2000   positive    104
# 15  2001   positive     46
# 21  2002   positive    359
# 27  2003   positive    523
# 33  2004   positive   2012
# 39  2005   positive   4756
# 45  2006   positive  23298
# 51  2007   positive  76998

# %%
neg2
# Out:
#     year sentiments   size
# 3   1999   negative      9
# 8   2000   negative     15
# 14  2001   negative     14
# 20  2002   negative     57
# 26  2003   negative    100
# 32  2004   negative    432
# 38  2005   negative   1049
# 44  2006   negative   4626
# 50  2007   negative  15966

# %%
# you can find other color pattern here: https://matplotlib.org/stable/gallery/color/named_colors.html
#正負面折線圖
colors = ["tab:blue",  "tab:orange"]
fig, ax = plt.subplots()

ax.bar(pos2['year'],
       pos2['size'],
       color = colors[0],
       alpha = 0.4,
       align='center')
ax.bar(neg2['year'],
       neg2['size'],
       color = colors[1],
       alpha = 0.4,
       align='center')
plt.xlabel('year')
plt.ylabel('size')

ax.legend(['positive','negative'], loc ='upper right')
plt.show()

# %%
sentiment_count2.groupby('year')['size'].transform(lambda n : n/n.sum())
# Out:
# 3     0.290323
# 4     0.709677
# 8     0.126050
# 9     0.873950
# 14    0.233333
# 15    0.766667
# 20    0.137019
# 21    0.862981
# 26    0.160514
# 27    0.839486
# 32    0.176759
# 33    0.823241
# 38    0.180706
# 39    0.819294
# 44    0.165664
# 45    0.834336
# 50    0.171744
# 51    0.828256
# Name: size, dtype: float64

# %%
#計算字詞情緒比例
sentiment_count2 = sentiment_count2.assign(
    ratio=sentiment_count2.groupby("year")["size"].transform(lambda n: n / n.sum())
)
sentiment_count2
# Out:
#     year sentiments   size     ratio
# 3   1999   negative      9  0.290323
# 4   1999   positive     22  0.709677
# 8   2000   negative     15  0.126050
# 9   2000   positive    104  0.873950
# 14  2001   negative     14  0.233333
# 15  2001   positive     46  0.766667
# 20  2002   negative     57  0.137019
# 21  2002   positive    359  0.862981
# 26  2003   negative    100  0.160514
# 27  2003   positive    523  0.839486
# 32  2004   negative    432  0.176759
# 33  2004   positive   2012  0.823241
# 38  2005   negative   1049  0.180706
# 39  2005   positive   4756  0.819294
# 44  2006   negative   4626  0.165664
# 45  2006   positive  23298  0.834336
# 50  2007   negative  15966  0.171744
# 51  2007   positive  76998  0.828256

# %%
#字詞情緒折線圖
pos2 = sentiment_count2[sentiment_count2['sentiments']=='positive']
neg2 = sentiment_count2[sentiment_count2['sentiments']=='negative']
fig, ax = plt.subplots()

ax.plot(pos2['year'],
       pos2['ratio'],
       color = colors[0])
ax.plot(neg2['year'],
       neg2['ratio'],
       color = colors[1])
plt.xlabel('year')
plt.ylabel('ratio')

ax.legend(['positive','negative'], loc ='upper right')

# %%
#不同年份字詞的正負向數量
mask = ~text_liwc_df2['sentiments'].isna()
text_sentiment_value2 = sentiment_count2.pivot_table(index='year', columns='sentiments', values='size', fill_value=0).reset_index().rename_axis(None, axis=1)
text_sentiment_value2.head(10)
# Out:
#    year  negative  positive
# 0  1999         9        22
# 1  2000        15       104
# 2  2001        14        46
# 3  2002        57       359
# 4  2003       100       523
# 5  2004       432      2012
# 6  2005      1049      4756
# 7  2006      4626     23298
# 8  2007     15966     76998

# %%
# 字詞sentiment 計算方式: positive - anger - anx - negative - sad
text_sentiment_value2["sentiment_value2"] = (
    text_sentiment_value2["positive"]
    - text_sentiment_value2["negative"]
)
text_sentiment_value2.head(10)
# Out:
#    year  negative  positive  sentiment_value2
# 0  1999         9        22                13
# 1  2000        15       104                89
# 2  2001        14        46                32
# 3  2002        57       359               302
# 4  2003       100       523               423
# 5  2004       432      2012              1580
# 6  2005      1049      4756              3707
# 7  2006      4626     23298             18672
# 8  2007     15966     76998             61032

# %%
#不同年份sentiment value折線圖
fig, ax = plt.subplots()
ax.plot(text_sentiment_value2['year'], text_sentiment_value2["sentiment_value2"])
ax.set_xlabel('year')
ax.set_ylabel('sentiment value')
# Out:
# Text(0, 0.5, 'sentiment value')

# %%
#以2006年為例，查詢2006年且為負面詞彙前5個
mask = (text_liwc_df2['year']=="2006") & (text_liwc_df2['sentiments']=='negative')
text_tf_by_ch_df2 = text_liwc_df2.loc[mask]
text_tf_by_ch_df2.head()
# Out:
#        year                                           sentence   token  \
# 96101  2006  Although it seems like it might cost a little ...   stale
# 96134  2006  The coffee is just OK Its very mild almost bor...    weak
# 96303  2006  I love this avocado oil rich easy to pour grea...     low
# 96376  2006  Did the groundhog leave my motherinlaws garden...   alone
# 96386  2006  Did the groundhog leave my motherinlaws garden...  ignore
#
#          word sentiments
# 96101   stale   negative
# 96134    weak   negative
# 96303     low   negative
# 96376   alone   negative
# 96386  ignore   negative

# %%
#計算出2006negative
word_count_count = pd.DataFrame(text_tf_by_ch_df2.groupby(['word']).size()).reset_index().rename(columns={0: "size"})
word_count_count = word_count_count.sort_values(by='size', ascending=False)
word_count_count
# Out:
#         word  size
# 20       bad   462
# 154  problem   329
# 123      low   280
# 22    bitter   187
# 44       cut   120
# ..       ...   ...
# 88    forbid     1
# 191   sicken     1
# 92     greed     1
# 187     shit     1
# 72     dread     1
#
# [265 rows x 2 columns]

# %%
## wordcloud 的 input 是一個 dict, key是 word, value 是次數
cloud = WordCloud(max_words=200, background_color="white", colormap="Oranges")
wc_45 = dict(zip(word_count_count['word'], word_count_count['size']))
cloud.generate_from_frequencies(wc_45)
# 繪圖
# plt.figure(figsize=(10,5), dpi=300)
plt.imshow(cloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
#從整個資料集集中計算出正負向情緒字的出現詞頻，並找出情緒的代表字
word_count = text_liwc_df2.groupby(['word', 'sentiments']).size().reset_index()
word_count.columns = ['word', 'sentiments','size']
word_count.sort_values("size", ascending=False)
# Out:
#             word sentiments   size
# 604         good     affect  14168
# 605         good   positive  14168
# 886         love   positive   9910
# 885         love     affect   9910
# 623        great     affect   8951
# ...          ...        ...    ...
# 1519  tragically     affect      1
# 1518      tragic        sad      1
# 1517      tragic   negative      1
# 1516      tragic     affect      1
# 884         lous   negative      1
#
# [1760 rows x 3 columns]

# %%
#繪出正負面前五多的詞彙
pos = word_count[word_count['sentiments']=='positive'].sort_values(['size'],ascending=True)
pos = pos[-5:]
neg = word_count[word_count['sentiments']=='negative'].sort_values(['size'],ascending=True)
neg = neg[-5:]
fig, ax = plt.subplots(1,2, figsize = (15, 5))

ax[0].barh(pos['word'],
           pos['size'],
           color = colors[0])
ax[0].set_xlabel('count')
ax[0].set_title("positive")

ax[1].xaxis.set_ticks([25,50,75,100,125,150,175])
ax[1].barh(neg['word'],
           neg['size'],
           color = colors[1])
ax[1].set_xlabel('count')
ax[1].set_title("negative")
ax[1].xaxis.set_ticks([300,600,900,1200,1500,1800,2100])
# Out:
# [<matplotlib.axis.XTick at 0x7fe57dcc5640>,
#  <matplotlib.axis.XTick at 0x7fe57dcc5610>,
#  <matplotlib.axis.XTick at 0x7fe57dcbe2b0>,
#  <matplotlib.axis.XTick at 0x7fe56e9c2850>,
#  <matplotlib.axis.XTick at 0x7fe56e9cb070>,
#  <matplotlib.axis.XTick at 0x7fe56e9c2d60>,
#  <matplotlib.axis.XTick at 0x7fe56e9cb2b0>]

# %%
#此以評論數最多的2007年為例，列出sentiments與size
mask = (text_liwc_df2['year']=="2007") & (~text_liwc_df2['sentiments'].isna())
word_count_2007 = text_liwc_df2.loc[mask, ['word','sentiments']]
word_count_2007 = word_count_2007.groupby(['word', 'sentiments']).size().reset_index(name='size')
word_count_2007.sort_values('size',ascending=False)
# Out:
#              word sentiments  size
# 585          good     affect  9991
# 586          good   positive  9991
# 859          love   positive  7108
# 858          love     affect  7108
# 601         great     affect  6384
# ...           ...        ...   ...
# 1033     pitiable        sad     1
# 837          lone        sad     1
# 72    anxiousness     affect     1
# 920         mooch   negative     1
# 1196       savage     affect     1
#
# [1691 rows x 3 columns]

# %%
#列出2007年前15多的正負面詞彙，並以圖呈現
pos = word_count_2007[word_count_2007['sentiments']=='positive'].sort_values(['size'],ascending=True)
pos = pos[-15:]
neg = word_count_2007[word_count_2007['sentiments']=='negative'].sort_values(['size'],ascending=True)
neg = neg[-15:]
fig, ax = plt.subplots(1,2, figsize = (15, 5))

ax[0].barh(pos['word'],
           pos['size'],
           color = colors[0])
ax[0].set_xlabel('count')
ax[1].barh(neg['word'],
           neg['size'],
           color = colors[1])
ax[1].set_xlabel('count')
# Out:
# Text(0.5, 0, 'count')

# %% [markdown]
# ##### 透過此研究，可以發現可能因為科技進步、行動裝置普及、社群媒體擴大，使得評論數隨著年份迅速增加
# ##### 從中也能發現關於Amazon food的正向評價也越來越高，表示從社群媒體中得到的建議，有助於Amazon服務的改善。
# ##### 另外像文字雲中的產品如coffee，明顯看出其較為顯著，是否能從顯著出現的產品中去進行改善，提升服務、產品品質
# ##### ，也是文字探勘研究帶來的一大助益。
